# %% [markdown]
# # Arithmetic-Operations using OpenCV

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

def add_images():
    image_1 = cv.imread("image_1.jpg", cv.IMREAD_COLOR)
    image_2 = cv.imread("image_2.jpg", cv.IMREAD_COLOR)
    if image_1.shape != image_2.shape:
        print("Images are not the same size, resizing...")
        image_2 = cv.resize(image_2, (image_1.shape[1], image_1.shape[0]))    
    
    result_add_images = cv.add(image_1, image_2)
    return result_add_images

def sub_images():
    image_1 = cv.imread("image_1.jpg", cv.IMREAD_COLOR)
    image_2 = cv.imread("image_2.jpg", cv.IMREAD_COLOR)
    
    if image_1.shape != image_2.shape:
        print("Images are not the same size, resizing...")
        image_2 = cv.resize(image_2, (image_1.shape[1], image_1.shape[0]))
        
    result_subtract_images = cv.subtract(image_1, image_2)
    return result_subtract_images

def mul_images():
    image_1 = cv.imread("image_1.jpg", cv.IMREAD_COLOR)
    image_2 = cv.imread("image_2.jpg", cv.IMREAD_COLOR)
    
    if image_1.shape != image_2.shape:
        print("Images are not the same size, resizing...")
        image_2 = cv.resize(image_2, (image_1.shape[1], image_1.shape[0]))
        
    result_multiplied_images = cv.multiply(image_1, image_2)
    return result_multiplied_images

def div_images():
    image_1 = cv.imread("image_1.jpg", cv.IMREAD_COLOR)
    image_2 = cv.imread("image_2.jpg", cv.IMREAD_COLOR)
    
    if image_1.shape != image_2.shape:
        print("Images are not the same size, resizing...")
        image_2 = cv.resize(image_2, (image_1.shape[1], image_1.shape[0]))
        
    result_divided_images = cv.divide(image_1, image_2)
    return result_divided_images

result_sub = sub_images() 
result_mul = mul_images()
result_add = add_images() 
result_div = div_images()


result_sub_rgb = cv.cvtColor(result_sub, cv.COLOR_BGR2RGB)
result_mul_rgb = cv.cvtColor(result_mul, cv.COLOR_BGR2RGB)
result_add_rgb = cv.cvtColor(result_add, cv.COLOR_BGR2RGB)
result_div_rgb = cv.cvtColor(result_div, cv.COLOR_BGR2RGB)

# %% [markdown]
# # Plotting Outputs

# %%
#Plotting all the Arithmetic Outputs
fig, axs = plt.subplots(2, 2, figsize=(10, 10))

axs[0, 0].imshow(result_sub_rgb)
axs[0, 0].set_title('Subtraction')
axs[0, 0].axis('off')

axs[0, 1].imshow(result_mul_rgb)
axs[0, 1].set_title('Multiplication')
axs[0, 1].axis('off')

axs[1, 0].imshow(result_add_rgb)
axs[1, 0].set_title('Addition')
axs[1, 0].axis('off')

axs[1, 1].imshow(result_div_rgb)
axs[1, 1].set_title('Division')
axs[1, 1].axis('off')


plt.show()
